# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\amanp\\Documents\\Kidney-Disease-Classification-Deep-Learning-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\amanp\\Documents\\Kidney-Disease-Classification-Deep-Learning-Project'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    

    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])

        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.IMAGE_SIZE,
            params_learning_rate=self.params.LEARNING_RATE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weights=self.params.WEIGHTS,
            params_classes=self.params.CLASSES
        )

        return prepare_base_model_config

# %%
pip uninstall -y numpy
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\amanp\.conda\envs\cnncls\Lib\site-packages\~-mpy.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\amanp\.conda\envs\cnncls\Lib\site-packages\~~mpy'.
# You can safely remove it manually.

# %%
pip install --upgrade --force-reinstall "numpy<2.0" "tensorflow==2.15.*" "ml-dtypes<0.3.2"
# Out:
# Collecting numpy<2.0
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting tensorflow==2.15.*
#   Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting ml-dtypes<0.3.2
#   Using cached ml_dtypes-0.3.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting tensorflow-intel==2.15.1 (from tensorflow==2.15.*)
#   Using cached tensorflow_intel-2.15.1-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached h5py-3.14.0-cp310-cp310-win_amd64.whl.metadata (2.7 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting packaging (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting setuptools (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting six>=1.12.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached wrapt-1.14.2-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached grpcio-1.74.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached charset_normalizer-3.4.3-cp310-cp310-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow==2.15.*)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached tensorflow-2.15.1-cp310-cp310-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.1-cp310-cp310-win_amd64.whl (300.9 MB)
# Using cached ml_dtypes-0.3.1-cp310-cp310-win_amd64.whl (126 kB)
# Using cached grpcio-1.74.0-cp310-cp310-win_amd64.whl (4.5 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp310-cp310-win_amd64.whl (107 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached wrapt-1.14.2-cp310-cp310-win_amd64.whl (35 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached markdown-3.8.2-py3-none-any.whl (106 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, setuptools, pyasn1, protobuf, packaging, opt-einsum, oauthlib, numpy, MarkupSafe, markdown, keras, idna, grpcio, gast, charset_normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, ml-dtypes, h5py, google-pasta, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#
#   Attempting uninstall: libclang
#
#     Found existing installation: libclang 18.1.1
#
#     Uninstalling libclang-18.1.1:
#
#       Successfully uninstalled libclang-18.1.1
#
#    ----------------------------------------  0/42 [libclang]
#    ----------------------------------------  0/42 [libclang]
#   Attempting uninstall: flatbuffers
#    ----------------------------------------  0/42 [libclang]
#     Found existing installation: flatbuffers 25.2.10
#    ----------------------------------------  0/42 [libclang]
#     Uninstalling flatbuffers-25.2.10:
#    ----------------------------------------  0/42 [libclang]
#       Successfully uninstalled flatbuffers-25.2.10
#    ----------------------------------------  0/42 [libclang]
#     ---------------------------------------  1/42 [flatbuffers]
#   Attempting uninstall: wrapt
#     ---------------------------------------  1/42 [flatbuffers]
#     Found existing installation: wrapt 1.14.2
#     ---------------------------------------  1/42 [flatbuffers]
#     Uninstalling wrapt-1.14.2:
#     ---------------------------------------  1/42 [flatbuffers]
#       Successfully uninstalled wrapt-1.14.2
#     ---------------------------------------  1/42 [flatbuffers]
#    - --------------------------------------  2/42 [wrapt]
#   Attempting uninstall: wheel
#    - --------------------------------------  2/42 [wrapt]
#     Found existing installation: wheel 0.45.1
#    - --------------------------------------  2/42 [wrapt]
#     Uninstalling wheel-0.45.1:
#    - --------------------------------------  2/42 [wrapt]
#       Successfully uninstalled wheel-0.45.1
#    - --------------------------------------  2/42 [wrapt]
#    -- -------------------------------------  3/42 [wheel]
#    -- -------------------------------------  3/42 [wheel]
#    -- -------------------------------------  3/42 [wheel]
#   Attempting uninstall: urllib3
#    -- -------------------------------------  3/42 [wheel]
#     Found existing installation: urllib3 2.5.0
#    -- -------------------------------------  3/42 [wheel]
#     Uninstalling urllib3-2.5.0:
#    -- -------------------------------------  3/42 [wheel]
#       Successfully uninstalled urllib3-2.5.0
#    -- -------------------------------------  3/42 [wheel]
#    --- ------------------------------------  4/42 [urllib3]
#    --- ------------------------------------  4/42 [urllib3]
#    --- ------------------------------------  4/42 [urllib3]
#   Attempting uninstall: typing-extensions
#    --- ------------------------------------  4/42 [urllib3]
#     Found existing installation: typing_extensions 4.14.1
#    --- ------------------------------------  4/42 [urllib3]
#     Uninstalling typing_extensions-4.14.1:
#    --- ------------------------------------  4/42 [urllib3]
#    ---- -----------------------------------  5/42 [typing-extensions]
#    ---- -----------------------------------  5/42 [typing-extensions]
#    ---- -----------------------------------  5/42 [typing-extensions]
#    ---- -----------------------------------  5/42 [typing-extensions]
#    ---- -----------------------------------  5/42 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.14.1
#    ---- -----------------------------------  5/42 [typing-extensions]
#   Attempting uninstall: termcolor
#    ---- -----------------------------------  5/42 [typing-extensions]
#     Found existing installation: termcolor 3.1.0
#    ---- -----------------------------------  5/42 [typing-extensions]
#    ----- ----------------------------------  6/42 [termcolor]
#     Uninstalling termcolor-3.1.0:
#    ----- ----------------------------------  6/42 [termcolor]
#       Successfully uninstalled termcolor-3.1.0
#    ----- ----------------------------------  6/42 [termcolor]
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#    ----- ----------------------------------  6/42 [termcolor]
#     Found existing installation: tensorflow-io-gcs-filesystem 0.31.0
#    ----- ----------------------------------  6/42 [termcolor]
#     Uninstalling tensorflow-io-gcs-filesystem-0.31.0:
#    ----- ----------------------------------  6/42 [termcolor]
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.31.0
#    ----- ----------------------------------  6/42 [termcolor]
#   Attempting uninstall: tensorflow-estimator
#    ----- ----------------------------------  6/42 [termcolor]
#     Found existing installation: tensorflow-estimator 2.15.0
#    ----- ----------------------------------  6/42 [termcolor]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#     Uninstalling tensorflow-estimator-2.15.0:
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#       Successfully uninstalled tensorflow-estimator-2.15.0
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#   Attempting uninstall: tensorboard-data-server
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#     Found existing installation: tensorboard-data-server 0.7.2
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#     Uninstalling tensorboard-data-server-0.7.2:
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#       Successfully uninstalled tensorboard-data-server-0.7.2
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#   Attempting uninstall: six
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#     Found existing installation: six 1.17.0
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#     Uninstalling six-1.17.0:
#    ------- --------------------------------  8/42 [tensorflow-estimator]
#    --------- ------------------------------ 10/42 [six]
#    --------- ------------------------------ 10/42 [six]
#    --------- ------------------------------ 10/42 [six]
#    --------- ------------------------------ 10/42 [six]
#    --------- ------------------------------ 10/42 [six]
#       Successfully uninstalled six-1.17.0
#    --------- ------------------------------ 10/42 [six]
#   Attempting uninstall: setuptools
#    --------- ------------------------------ 10/42 [six]
#     Found existing installation: setuptools 80.9.0
#    --------- ------------------------------ 10/42 [six]
#    ---------- ----------------------------- 11/42 [setuptools]
#     Uninstalling setuptools-80.9.0:
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#       Successfully uninstalled setuptools-80.9.0
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#    ---------- ----------------------------- 11/42 [setuptools]
#   Attempting uninstall: pyasn1
#    ---------- ----------------------------- 11/42 [setuptools]
#     Found existing installation: pyasn1 0.6.1
#    ---------- ----------------------------- 11/42 [setuptools]
#     Uninstalling pyasn1-0.6.1:
#    ---------- ----------------------------- 11/42 [setuptools]
#       Successfully uninstalled pyasn1-0.6.1
#    ---------- ----------------------------- 11/42 [setuptools]
#    ----------- ---------------------------- 12/42 [pyasn1]
#    ----------- ---------------------------- 12/42 [pyasn1]
#    ----------- ---------------------------- 12/42 [pyasn1]
#   Attempting uninstall: protobuf
#    ----------- ---------------------------- 12/42 [pyasn1]
#     Found existing installation: protobuf 4.25.8
#    ----------- ---------------------------- 12/42 [pyasn1]
#     Uninstalling protobuf-4.25.8:
#    ----------- ---------------------------- 12/42 [pyasn1]
#       Successfully uninstalled protobuf-4.25.8
#    ----------- ---------------------------- 12/42 [pyasn1]
#    ------------ --------------------------- 13/42 [protobuf]
#    ------------ --------------------------- 13/42 [protobuf]
#    ------------ --------------------------- 13/42 [protobuf]
#    ------------ --------------------------- 13/42 [protobuf]
#   Attempting uninstall: packaging
#    ------------ --------------------------- 13/42 [protobuf]
#     Found existing installation: packaging 25.0
#    ------------ --------------------------- 13/42 [protobuf]
#     Uninstalling packaging-25.0:
#    ------------ --------------------------- 13/42 [protobuf]
#       Successfully uninstalled packaging-25.0
#    ------------ --------------------------- 13/42 [protobuf]
#    ------------- -------------------------- 14/42 [packaging]
#    ------------- -------------------------- 14/42 [packaging]
#   Attempting uninstall: opt-einsum
#    ------------- -------------------------- 14/42 [packaging]
#     Found existing installation: opt_einsum 3.4.0
#    ------------- -------------------------- 14/42 [packaging]
#     Uninstalling opt_einsum-3.4.0:
#    ------------- -------------------------- 14/42 [packaging]
#       Successfully uninstalled opt_einsum-3.4.0
#    ------------- -------------------------- 14/42 [packaging]
#    -------------- ------------------------- 15/42 [opt-einsum]
#    -------------- ------------------------- 15/42 [opt-einsum]
#   Attempting uninstall: oauthlib
#    -------------- ------------------------- 15/42 [opt-einsum]
#     Found existing installation: oauthlib 3.3.1
#    -------------- ------------------------- 15/42 [opt-einsum]
#    --------------- ------------------------ 16/42 [oauthlib]
#     Uninstalling oauthlib-3.3.1:
#    --------------- ------------------------ 16/42 [oauthlib]
#       Successfully uninstalled oauthlib-3.3.1
#    --------------- ------------------------ 16/42 [oauthlib]
#    --------------- ------------------------ 16/42 [oauthlib]
#    --------------- ------------------------ 16/42 [oauthlib]
#    --------------- ------------------------ 16/42 [oauthlib]
#    --------------- ------------------------ 16/42 [oauthlib]
#    --------------- ------------------------ 16/42 [oauthlib]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#    ---------------- ----------------------- 17/42 [numpy]
#   Attempting uninstall: MarkupSafe
#    ---------------- ----------------------- 17/42 [numpy]
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#     Found existing installation: MarkupSafe 3.0.2
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#     Uninstalling MarkupSafe-3.0.2:
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#       Successfully uninstalled MarkupSafe-3.0.2
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#   Attempting uninstall: markdown
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#     Found existing installation: Markdown 3.8.2
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#     Uninstalling Markdown-3.8.2:
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#       Successfully uninstalled Markdown-3.8.2
#    ----------------- ---------------------- 18/42 [MarkupSafe]
#    ------------------ --------------------- 19/42 [markdown]
#    ------------------ --------------------- 19/42 [markdown]
#    ------------------ --------------------- 19/42 [markdown]
#    ------------------ --------------------- 19/42 [markdown]
#   Attempting uninstall: keras
#    ------------------ --------------------- 19/42 [markdown]
#     Found existing installation: keras 2.15.0
#    ------------------ --------------------- 19/42 [markdown]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#     Uninstalling keras-2.15.0:
#    ------------------- -------------------- 20/42 [keras]
#       Successfully uninstalled keras-2.15.0
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#    ------------------- -------------------- 20/42 [keras]
#   Attempting uninstall: idna
#    ------------------- -------------------- 20/42 [keras]
#     Found existing installation: idna 3.10
#    ------------------- -------------------- 20/42 [keras]
#     Uninstalling idna-3.10:
#    ------------------- -------------------- 20/42 [keras]
#       Successfully uninstalled idna-3.10
#    ------------------- -------------------- 20/42 [keras]
#    -------------------- ------------------- 21/42 [idna]
#    -------------------- ------------------- 21/42 [idna]
#   Attempting uninstall: grpcio
#    -------------------- ------------------- 21/42 [idna]
#     Found existing installation: grpcio 1.74.0
#    -------------------- ------------------- 21/42 [idna]
#     Uninstalling grpcio-1.74.0:
#    -------------------- ------------------- 21/42 [idna]
#       Successfully uninstalled grpcio-1.74.0
#    -------------------- ------------------- 21/42 [idna]
#    -------------------- ------------------- 22/42 [grpcio]
#    -------------------- ------------------- 22/42 [grpcio]
#    -------------------- ------------------- 22/42 [grpcio]
#    -------------------- ------------------- 22/42 [grpcio]
#   Attempting uninstall: gast
#    -------------------- ------------------- 22/42 [grpcio]
#     Found existing installation: gast 0.6.0
#    -------------------- ------------------- 22/42 [grpcio]
#     Uninstalling gast-0.6.0:
#    -------------------- ------------------- 22/42 [grpcio]
#       Successfully uninstalled gast-0.6.0
#    -------------------- ------------------- 22/42 [grpcio]
#    --------------------- ------------------ 23/42 [gast]
#   Attempting uninstall: charset_normalizer
#    --------------------- ------------------ 23/42 [gast]
#     Found existing installation: charset-normalizer 3.4.3
#    --------------------- ------------------ 23/42 [gast]
#     Uninstalling charset-normalizer-3.4.3:
#    --------------------- ------------------ 23/42 [gast]
#       Successfully uninstalled charset-normalizer-3.4.3
#    --------------------- ------------------ 23/42 [gast]
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#   Attempting uninstall: certifi
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#     Found existing installation: certifi 2025.8.3
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#     Uninstalling certifi-2025.8.3:
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#       Successfully uninstalled certifi-2025.8.3
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#   Attempting uninstall: cachetools
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#     Found existing installation: cachetools 5.5.2
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#     Uninstalling cachetools-5.5.2:
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#       Successfully uninstalled cachetools-5.5.2
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#   Attempting uninstall: absl-py
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#     Found existing installation: absl-py 2.3.1
#    ---------------------- ----------------- 24/42 [charset_normalizer]
#    ------------------------- -------------- 27/42 [absl-py]
#     Uninstalling absl-py-2.3.1:
#    ------------------------- -------------- 27/42 [absl-py]
#       Successfully uninstalled absl-py-2.3.1
#    ------------------------- -------------- 27/42 [absl-py]
#    ------------------------- -------------- 27/42 [absl-py]
#    ------------------------- -------------- 27/42 [absl-py]
#   Attempting uninstall: werkzeug
#    ------------------------- -------------- 27/42 [absl-py]
#     Found existing installation: Werkzeug 3.1.3
#    ------------------------- -------------- 27/42 [absl-py]
#     Uninstalling Werkzeug-3.1.3:
#    ------------------------- -------------- 27/42 [absl-py]
#       Successfully uninstalled Werkzeug-3.1.3
#    ------------------------- -------------- 27/42 [absl-py]
#    -------------------------- ------------- 28/42 [werkzeug]
#    -------------------------- ------------- 28/42 [werkzeug]
#    -------------------------- ------------- 28/42 [werkzeug]
#    -------------------------- ------------- 28/42 [werkzeug]
#    -------------------------- ------------- 28/42 [werkzeug]
#   Attempting uninstall: rsa
#    -------------------------- ------------- 28/42 [werkzeug]
#     Found existing installation: rsa 4.9.1
#    -------------------------- ------------- 28/42 [werkzeug]
#     Uninstalling rsa-4.9.1:
#    -------------------------- ------------- 28/42 [werkzeug]
#       Successfully uninstalled rsa-4.9.1
#    -------------------------- ------------- 28/42 [werkzeug]
#    --------------------------- ------------ 29/42 [rsa]
#    --------------------------- ------------ 29/42 [rsa]
#    --------------------------- ------------ 29/42 [rsa]
#    --------------------------- ------------ 29/42 [rsa]
#    --------------------------- ------------ 29/42 [rsa]
#   Attempting uninstall: requests
#    --------------------------- ------------ 29/42 [rsa]
#     Found existing installation: requests 2.32.4
#    --------------------------- ------------ 29/42 [rsa]
#     Uninstalling requests-2.32.4:
#    --------------------------- ------------ 29/42 [rsa]
#       Successfully uninstalled requests-2.32.4
#    --------------------------- ------------ 29/42 [rsa]
#    ---------------------------- ----------- 30/42 [requests]
#    ---------------------------- ----------- 30/42 [requests]
#   Attempting uninstall: pyasn1-modules
#    ---------------------------- ----------- 30/42 [requests]
#     Found existing installation: pyasn1_modules 0.4.2
#    ---------------------------- ----------- 30/42 [requests]
#     Uninstalling pyasn1_modules-0.4.2:
#    ---------------------------- ----------- 30/42 [requests]
#       Successfully uninstalled pyasn1_modules-0.4.2
#    ---------------------------- ----------- 30/42 [requests]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#   Attempting uninstall: ml-dtypes
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#     Found existing installation: ml-dtypes 0.3.1
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#     Uninstalling ml-dtypes-0.3.1:
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#       Successfully uninstalled ml-dtypes-0.3.1
#    ----------------------------- ---------- 31/42 [pyasn1-modules]
#    ------------------------------ --------- 32/42 [ml-dtypes]
#   Attempting uninstall: h5py
#    ------------------------------ --------- 32/42 [ml-dtypes]
#     Found existing installation: h5py 3.14.0
#    ------------------------------ --------- 32/42 [ml-dtypes]
#     Uninstalling h5py-3.14.0:
#    ------------------------------ --------- 32/42 [ml-dtypes]
#       Successfully uninstalled h5py-3.14.0
#    ------------------------------ --------- 32/42 [ml-dtypes]
#    ------------------------------- -------- 33/42 [h5py]
#    ------------------------------- -------- 33/42 [h5py]
#    ------------------------------- -------- 33/42 [h5py]
#    ------------------------------- -------- 33/42 [h5py]
#    ------------------------------- -------- 33/42 [h5py]
#   Attempting uninstall: google-pasta
#    ------------------------------- -------- 33/42 [h5py]
#     Found existing installation: google-pasta 0.2.0
#    ------------------------------- -------- 33/42 [h5py]
#     Uninstalling google-pasta-0.2.0:
#    ------------------------------- -------- 33/42 [h5py]
#       Successfully uninstalled google-pasta-0.2.0
#    ------------------------------- -------- 33/42 [h5py]
#    -------------------------------- ------- 34/42 [google-pasta]
#    -------------------------------- ------- 34/42 [google-pasta]
#   Attempting uninstall: astunparse
#    -------------------------------- ------- 34/42 [google-pasta]
#     Found existing installation: astunparse 1.6.3
#    -------------------------------- ------- 34/42 [google-pasta]
#     Uninstalling astunparse-1.6.3:
#    -------------------------------- ------- 34/42 [google-pasta]
#       Successfully uninstalled astunparse-1.6.3
#    -------------------------------- ------- 34/42 [google-pasta]
#   Attempting uninstall: requests-oauthlib
#    -------------------------------- ------- 34/42 [google-pasta]
#     Found existing installation: requests-oauthlib 2.0.0
#    -------------------------------- ------- 34/42 [google-pasta]
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#     Uninstalling requests-oauthlib-2.0.0:
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#       Successfully uninstalled requests-oauthlib-2.0.0
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#   Attempting uninstall: google-auth
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#     Found existing installation: google-auth 2.40.3
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#     Uninstalling google-auth-2.40.3:
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#       Successfully uninstalled google-auth-2.40.3
#    ---------------------------------- ----- 36/42 [requests-oauthlib]
#    ----------------------------------- ---- 37/42 [google-auth]
#    ----------------------------------- ---- 37/42 [google-auth]
#    ----------------------------------- ---- 37/42 [google-auth]
#    ----------------------------------- ---- 37/42 [google-auth]
#    ----------------------------------- ---- 37/42 [google-auth]
#    ----------------------------------- ---- 37/42 [google-auth]
#   Attempting uninstall: google-auth-oauthlib
#    ----------------------------------- ---- 37/42 [google-auth]
#     Found existing installation: google-auth-oauthlib 1.2.2
#    ----------------------------------- ---- 37/42 [google-auth]
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#     Uninstalling google-auth-oauthlib-1.2.2:
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#       Successfully uninstalled google-auth-oauthlib-1.2.2
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#   Attempting uninstall: tensorboard
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#     Found existing installation: tensorboard 2.15.2
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#     Uninstalling tensorboard-2.15.2:
#    ------------------------------------ --- 38/42 [google-auth-oauthlib]
#    ------------------------------------- -- 39/42 [tensorboard]
#       Successfully uninstalled tensorboard-2.15.2
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#    ------------------------------------- -- 39/42 [tensorboard]
#   Attempting uninstall: tensorflow-intel
#    ------------------------------------- -- 39/42 [tensorboard]
#     Found existing installation: tensorflow-intel 2.15.1
#    ------------------------------------- -- 39/42 [tensorboard]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#     Uninstalling tensorflow-intel-2.15.1:
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#       Successfully uninstalled tensorflow-intel-2.15.1
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    -------------------------------------- - 40/42 [tensorflow-intel]
#   Attempting uninstall: tensorflow
#    -------------------------------------- - 40/42 [tensorflow-intel]
#     Found existing installation: tensorflow 2.15.1
#    -------------------------------------- - 40/42 [tensorflow-intel]
#     Uninstalling tensorflow-2.15.1:
#    -------------------------------------- - 40/42 [tensorflow-intel]
#       Successfully uninstalled tensorflow-2.15.1
#    -------------------------------------- - 40/42 [tensorflow-intel]
#    ---------------------------------------- 42/42 [tensorflow]
#
# Successfully installed MarkupSafe-3.0.2 absl-py-2.3.1 astunparse-1.6.3 cachetools-5.5.2 certifi-2025.8.3 charset_normalizer-3.4.3 flatbuffers-25.2.10 gast-0.6.0 google-auth-2.40.3 google-auth-oauthlib-1.2.2 google-pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 idna-3.10 keras-2.15.0 libclang-18.1.1 markdown-3.8.2 ml-dtypes-0.3.1 numpy-1.26.4 oauthlib-3.3.1 opt-einsum-3.4.0 packaging-25.0 protobuf-4.25.8 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-2.32.4 requests-oauthlib-2.0.0 rsa-4.9.1 setuptools-80.9.0 six-1.17.0 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.1 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.1.0 typing-extensions-4.14.1 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.14.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 2.2.2 requires packaging<24, but you have packaging 25.0 which is incompatible.

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
# Out:
# [2025-08-17 00:02:14,653: WARNING: module_wrapper: From c:\Users\amanp\.conda\envs\cnncls\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ]

# %%
class PrepareBaseModel:
    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config

    
    def get_base_model(self):
        self.model = tf.keras.applications.vgg16.VGG16(
            input_shape=self.config.params_image_size,
            weights=self.config.params_weights,
            include_top=self.config.params_include_top
        )

        self.save_model(path=self.config.base_model_path, model=self.model)

    

    @staticmethod
    def _prepare_full_model(model, classes, freeze_all, freeze_till, learning_rate):
        if freeze_all:
            for layer in model.layers:
                model.trainable = False
        elif (freeze_till is not None) and (freeze_till > 0):
            for layer in model.layers[:-freeze_till]:
                model.trainable = False

        flatten_in = tf.keras.layers.Flatten()(model.output)
        prediction = tf.keras.layers.Dense(
            units=classes,
            activation="softmax"
        )(flatten_in)

        full_model = tf.keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        full_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=["accuracy"]
        )

        full_model.summary()
        return full_model
    
    
    def update_base_model(self):
        self.full_model = self._prepare_full_model(
            model=self.model,
            classes=self.config.params_classes,
            freeze_all=True,
            freeze_till=None,
            learning_rate=self.config.params_learning_rate
        )

        self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

    
        
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)

# %%
try:
    config = ConfigurationManager()
    prepare_base_model_config = config.get_prepare_base_model_config()
    prepare_base_model = PrepareBaseModel(config=prepare_base_model_config)
    prepare_base_model.get_base_model()
    prepare_base_model.update_base_model()
except Exception as e:
    raise e
# Out:
# [2025-08-17 00:02:23,489: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-08-17 00:02:23,493: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-08-17 00:02:23,494: INFO: common: created directory at: artifacts]
# [2025-08-17 00:02:23,495: INFO: common: created directory at: artifacts/prepare_base_model]
# [2025-08-17 00:02:23,773: WARNING: module_wrapper: From c:\Users\amanp\.conda\envs\cnncls\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# ]
# [2025-08-17 00:02:23,965: WARNING: module_wrapper: From c:\Users\amanp\.conda\envs\cnncls\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# ]
# [2025-08-17 00:02:24,441: WARNING: saving_utils: Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# c:\Users\amanp\.conda\envs\cnncls\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14764866 (56.32 MB)
# Trainable params: 50178 (196.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
